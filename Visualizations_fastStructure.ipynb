# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# %pylab inline

sampleinfo = pd.read_csv("~/public/1000Genomes/igsr_samples.tsv", sep="\t")
sample_to_pop = dict(zip(list(sampleinfo["Sample name"]), list(sampleinfo["Population code"])))
samples = [line.split()[0] for line in open("structure_out_as/admixture_chr1.pruned.fam", "r").readlines()]
pops = [sample_to_pop.get(item, "NA") for item in samples]

fig = plt.figure()
fig.set_size_inches((10, 8))

plotind = 1
for K in [3, 5]:
    ax = fig.add_subplot(3, 1, plotind)
    
    data = pd.read_csv("structure_out_as/fS_run_K.%s.meanQ"%K, delim_whitespace=True, header=None)
    cols = list(data.columns)
    data["sample"] = samples
    data["pop"] = pops
    data = data.sort_values(["pop"]+cols)
    data.plot.bar(stacked=True, ax=ax, width=1)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
    # Only plot label for first sample in each pop
    xticklabels = []
    currpop = ""
    for i in range(data.shape[0]):
        if data["pop"].values[i] == currpop:
            xticklabels.append("")
        else:
            xticklabels.append(data["pop"].values[i])
            currpop = data["pop"].values[i]
    ax.set_xticklabels(xticklabels)
    ax.set_title(f"fastStructure_ALL, K={K}")
    
    plotind += 1
fig.tight_layout()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /tmp/ipykernel_121/434485859.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("structure_out_as/fS_run_K.%s.meanQ"%K, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/434485859.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("structure_out_as/fS_run_K.%s.meanQ"%K, delim_whitespace=True, header=None)

# %% [markdown]
# # Invert K=2

# %%
# %pylab inline

sampleinfo = pd.read_csv("~/public/1000Genomes/igsr_samples.tsv", sep="\t")
sample_to_pop = dict(zip(list(sampleinfo["Sample name"]), list(sampleinfo["Population code"])))
samples = [line.split()[0] for line in open("structure_out_as/admixture_chr1.pruned.fam", "r").readlines()]
pops = [sample_to_pop.get(item, "NA") for item in samples]

fig = plt.figure()
fig.set_size_inches((10, 8))

plotind = 1
for K in [2]:
    ax = fig.add_subplot(3, 1, plotind)
    
    data = pd.read_csv("structure_out_as/fS_run_K.%s.meanQ"%K, delim_whitespace=True, header=None)
    data = 1- data
    cols = list(data.columns)
    data["sample"] = samples
    data["pop"] = pops
    data = data.sort_values(["pop"]+cols)
    data.plot.bar(stacked=True, ax=ax, width=1)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
    # Only plot label for first sample in each pop
    xticklabels = []
    currpop = ""
    for i in range(data.shape[0]):
        if data["pop"].values[i] == currpop:
            xticklabels.append("")
        else:
            xticklabels.append(data["pop"].values[i])
            currpop = data["pop"].values[i]
    ax.set_xticklabels(xticklabels)
    ax.set_title("fastStructure_ALL, K=2")
    ax.legend(loc='upper right')
    
    plotind += 1
fig.tight_layout()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /tmp/ipykernel_121/463062486.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("structure_out_as/fS_run_K.%s.meanQ"%K, delim_whitespace=True, header=None)

# %% [markdown]
# # Plots for each Chromosome

# %%
# %pylab inline

# Load sample info
sampleinfo = pd.read_csv("~/public/1000Genomes/igsr_samples.tsv", sep="\t")
sample_to_pop = dict(zip(list(sampleinfo["Sample name"]), list(sampleinfo["Population code"])))
samples = [line.split()[0] for line in open("structure_out_as/admixture_chr1.pruned.fam", "r").readlines()]
pops = [sample_to_pop.get(item, "NA") for item in samples]


for chrom in range(1,23):
    fig = plt.figure(figsize=(10, 8))
    
    plotind = 1
    for K in [2, 3, 5]:
        ax = fig.add_subplot(3, 1, plotind)
        
        # Update file path for data
        data_file = f"structure_out/structure_chr{chrom}/fS_run_K.%s.meanQ"%K
        data = pd.read_csv(data_file, delim_whitespace=True, header=None)
        cols = list(data.columns)
        data["sample"] = samples
        data["pop"] = pops
        data = data.sort_values(["pop"]+cols)
        
        data.plot.bar(stacked=True, ax=ax, width=1, legend=False) # Turn off legend for each subplot for clarity
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.yaxis.set_ticks_position('left')
        ax.xaxis.set_ticks_position('bottom')
        
        # Only plot label for first sample in each pop
        xticklabels = []
        currpop = ""
        for i in range(data.shape[0]):
            if data["pop"].values[i] == currpop:
                xticklabels.append("")
            else:
                xticklabels.append(data["pop"].values[i])
                currpop = data["pop"].values[i]
        ax.set_xticklabels(xticklabels, rotation=45, ha='right')
        ax.set_title(f"Chr{chrom}, K={K}")
        
        plotind += 1

    fig.tight_layout()
    plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
# /tmp/ipykernel_121/1283788438.py:19: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(data_file, delim_whitespace=True, header=None)
